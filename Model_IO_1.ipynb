# %% [markdown]
# # 1、模型调用的分类
# 角度1：按照模型功能的不同
# 非对话模型：(LLMs、TextModeL)
# 对话模型：(ChatModels)(推荐)
# 嵌入模型：(Embedding Models)(RAG阶段学习)
#
# 角度2：按照模型调用时，参数书写的位置的不同(api-key、base_url、model-name)
# 硬编码的方式：将参数书写在代码中
# 使用环境变量的方式
# 使用配置文件的方式
#
# 角度3：具体API的调用
# 使用LangChain提供的API(推荐)
# 使用OpenAI 官方的API
# 使用其它平台提供的API

# %% [markdown]
# # 2、角度1：非对话模型的调用

# %%
import os
import dotenv
from langchain_openai import OpenAI
dotenv.load_dotenv()
os.environ["OPENAI_API_KEY"] = os.getenv("LLM_API_KEY")
os.environ["OPENAI_BASE_URL"] = os.getenv("LLM_BASE_URL")

# %%
llm = OpenAI(model=os.getenv("LLM_MODEL_ID"))
str=llm.invoke("介绍一下你自己。")
print(str)
print(type(str))
# Out:
#  我叫通义千问，是由阿里云研发的超大规模语言模型。我能够回答问题、创作文字，还能表达观点、撰写代码，是你的聪明好助手。如果你有任何问题或需要帮助，都可以找我哦。不过，我并不是真正的“人”，所以没有真实的生活经历和个人故事，只是个能持续进化的AI模型。如果你有任何问题或需要帮助，请随时告诉我，我会尽力提供支持。我们能够聊很多话题，比如科学、历史、文学等，也可以聊聊日常生活、娱乐资讯等。如果你有任何问题或需要帮助，请随时告诉我，我会尽力提供支持。在与你交流的过程中，我会不断学习和进步，以便更好地为你服务。希望我们可以愉快地交流！如果你有任何问题或需要帮助，请随时告诉我，我会尽力提供支持。让我们开始吧！如果你有任何问题或需要帮助，请随时告诉我，我会尽力提供支持。希望我们可以愉快地交流！如果你有任何问题或需要帮助，请随时告诉我，我会尽力提供支持。让我们开始吧！如果你有任何问题或需要帮助，请随时告诉我，我会尽力提供支持。希望我们可以愉快地交流！如果你有任何问题或需要帮助，请随时告诉我，我会尽力提供支持。让我们开始吧！如果你有任何问题或需要帮助
# <class 'str'>

# %% [markdown]
# # 2、角度1：对话模型的调用

# %%
import os
import dotenv
from langchain_openai import ChatOpenAI
from langchain_core.messages import HumanMessage, SystemMessage, AIMessage
dotenv.load_dotenv()
os.environ["OPENAI_API_KEY"] = os.getenv("LLM_API_KEY")
os.environ["OPENAI_BASE_URL"] = os.getenv("LLM_BASE_URL")

# %%
chat_model = ChatOpenAI(model=os.getenv("LLM_MODEL_ID"))

message = [SystemMessage(content="你是一个有帮助的助手。"),
           HumanMessage(content="介绍一下你自己。")
            ]

response = chat_model.invoke(message)

print(response.content)
print(type(response))
# Out:
# 您好！我是一个来自阿里云的语言模型，我叫通义千问。我是阿里云自主研发的超大规模语言模型，能够回答问题、创作文字，还能提供多语言翻译支持，帮助用户生成各种类型的文本，如文章、故事、诗歌等。如果您有任何问题或需要帮助，请随时告诉我，我会尽力提供支持。
# <class 'langchain_core.messages.ai.AIMessage'>

# %% [markdown]
# # 2、角度1：对话模型的调用

# %%
import os
import dotenv
from langchain_openai import OpenAIEmbeddings
dotenv.load_dotenv()
os.environ["OPENAI_API_KEY"] = os.getenv("LLM_API_KEY")
os.environ["OPENAI_BASE_URL"] = os.getenv("LLM_BASE_URL")

# %%
embeddings = OpenAIEmbeddings(model=os.getenv("LLM_EMBEDDING_MODEL_ID"))

res = embeddings.embed_query("介绍一下你自己。")
print(res)
print(type(res))
print(len(res))
# Out:
# [-0.010984010994434357, 0.0309526976197958, 0.015591536648571491, 0.017311131581664085, -0.002523854374885559, 0.03725513443350792, 0.03653109446167946, 0.05871303752064705, -0.003887599566951394, 0.008844803087413311, -0.02884639985859394, 0.04429806396365166, -0.022527508437633514, -0.011708050966262817, 0.05657383054494858, -0.06697367131710052, -0.01806808076798916, -0.0019859669264405966, 0.018775666132569313, -0.0026287578511983156, 0.025851508602499962, 0.0037333297077566385, -0.011370714753866196, 0.03287798538804054, -0.01002136804163456, 0.020306022837758064, -0.03233495354652405, 0.007655897177755833, -0.003099794965237379, -0.0025649929884821177, -0.023021170869469643, -0.04146772623062134, 0.03922978788614273, -0.044429708272218704, -0.018857942894101143, -0.05660673975944519, 0.014135229401290417, 0.02246168628334999, -0.04367275908589363, -7.964179530972615e-05, 0.025473032146692276, -0.036432359367609024, 0.011156793683767319, -0.05861430615186691, -0.0309197865426540
# ...

# %% [markdown]
# # 3、角度2：参数位置不同举例
# ## 3.1 硬编码方式

# %%
from langchain_openai import ChatOpenAI
# 调用非对话模型：
# llms = OpenAI(...)


# 调用对话模型：
chat_model = ChatOpenAI(
    # 必须要设置的3个参数
    model_name="", # 默认使用的是gpt-3.5-turbo模型
    base_url="",
    api_key="",

)

# 调用模型
response = chat_model.invoke("什么是langchain?")

# 查看响应的文本
# print(response.content)
print(response)
# Out:
# content='LangChain是一个概念框架，其目标是通过结合利用语言模型的强大功能与链式结构的方法，增强应用程序的功能。LangChain的概念由阿里云在2022年提出，旨在探索如何将最新的大语言模型（LLM）集成到各种各样的应用和系统中，使其能够进行更复杂、更场景化的任务处理。\n\nLangChain主要包含以下几个关键概念：\n\n1. 语言模型（Language Model）：一种机器学习模型，用于生成自然语言文本，基于给定的词语或短语生成后续的文本。\n2. 链接（Chain）：这里的链是指构建在LLM基础上的更复杂的应用程序。通过将简单的组件（语言模型、数据库、API等）链接起来，可以创建出能够完成更加复杂任务的应用程序。\n3. 环境（Environment）：设备、操作系统、编程语言、数据库等运行时环境。\n\nLangChain的主要应用场景包括但不限于：\n- 自动编程：利用语言模型生成代码，帮助程序员更快地编写程序。\n- 智能搜索与导航：结合搜索引擎和大语言模型，提供更精准、个性化的搜索结果。\n- 自动化报告生成：基于输入的企业数据或分析结果，自动生成报告。\n- 问答系统构建：将语言模型与知识库集成，构建能够回答复杂问题的系统。\n\n总之，LangChain是一个旨在利用大语言模型的强大能力，通过链式结构构建复杂应用的框架。' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 304, 'prompt_tokens': 33, 'total_tokens': 337, 'completion_tokens_details': None, 'prompt_tokens_details': None}, 'model_provider': 'openai', 'model_name': 'Qwen/Qwen2.5-7B-Instruct', 'system_fingerprint': '', 'id': '019be4706817d31e91e2e030fead085f', 'finish_reason': 'stop', 'logprobs': None} id='lc_run--019be47
# ...

# %%
from langchain_openai import OpenAI

# 调用非对话模型：
llm = OpenAI(
    # 必须要设置的3个参数
    model_name="",   # 默认使用的是gpt-3.5-turbo模型
    base_url="",
    api_key="",

)

# 调用模型
response = llm.invoke("什么是langchain?")

# 查看响应的文本
print(response)

# %% [markdown]
# ## 3.2 使用环境变量方式
# 说明：使用环境变量的方式，在jupyter中执行不合适，需要在.py文件中执行

# %%
from langchain_openai import ChatOpenAI


# 1、获取对话模型：
chat_model = ChatOpenAI(
    #必须要设置的3个参数
    model_name="",   #默认使用的是gpt-3.5-turbo模型
    base_url=os.environ[""],
    api_key=os.environ[""],

)

# 2、调用模型
response = chat_model.invoke("什么是langchain?")

# 3、查看响应的文本
# print(response.content)
print(response)

# %% [markdown]
# ## 3.3 配置文件的方式（推荐）
# 使用.env的配置文件
# 方式1：

# %%
from langchain_openai import ChatOpenAI
import os
import dotenv

# 加载配置文件
dotenv.load_dotenv()


# 1、获取对话模型：
chat_model = ChatOpenAI(
    #必须要设置的3个参数
    model_name="",   #默认使用的是gpt-3.5-turbo模型
    base_url=os.getenv(""),
    api_key=os.getenv(""),

)

# 2、调用模型
response = chat_model.invoke("什么是langchain?")

# 3、查看响应的文本
# print(response.content)
print(response)

# %% [markdown]
# 方式2：

# %%
from langchain_openai import ChatOpenAI
import os
import dotenv

# 加载配置文件
dotenv.load_dotenv()

os.environ["OPENAI_BASE_URL"] = os.getenv("OPENAI_BASE_URL")
os.environ["OPENAI_API_KEY"] = os.getenv("OPENAI_API_KEY1")

# 1、获取对话模型：
chat_model = ChatOpenAI(
    # 当没有显式的声明base_url和api_key的时候，默认会从环境变量中查找
)

# 2、调用模型
response = chat_model.invoke("什么是langchain?")

# 3、查看响应的文本
# print(response.content)
print(response)

# %% [markdown]
# 体会其它参数的使用：

# %%
from langchain_openai import ChatOpenAI
import os
import dotenv

# 加载配置文件
dotenv.load_dotenv()

os.environ["OPENAI_BASE_URL"] = os.getenv("OPENAI_BASE_URL")
os.environ["OPENAI_API_KEY"] = os.getenv("OPENAI_API_KEY1")

# 1、获取对话模型：
chat_model = ChatOpenAI(
    temperature=0.7,
    max_tokens=20,
)

# 2、调用模型
response = chat_model.invoke("什么是langchain?")

# 3、查看响应的文本
# print(response.content)
print(response)

# %% [markdown]
# # 4、角度3：使用各个平台的API的调用大模型（了解）
#
# ## 4.1 OpenAI的方式
#
# 调用非对话模型

# %%
from openai import OpenAI
import os
import dotenv

# 从环境变量读取API密钥（推荐安全存储）
client = OpenAI(
    api_key=os.getenv("LLM_API_KEY"),  # 填写自己的api-key
    base_url=os.getenv("LLM_BASE_URL")) # 通过代码示例获取

# 调用Completion接口
response = client.completions.create(
    model=os.getenv("LLM_MODEL_ID"),  # 非对话模型
    prompt="请将以下英文翻译成中文：'Artificial intelligence will reshape the future.'",
    max_tokens=100,  # 生成文本最大长度
    temperature=0.7,  # 控制随机性
)

# 提取结果
print(response.choices[0].text.strip())
# Out:
# '人工智能将会重塑未来。'
#
# 这句话的翻译简洁明了，直接表达了人工智能对未来社会的巨大影响。在中文语境中，“重塑未来”这一表达形象地传达了人工智能技术对未来社会结构、经济形态、生活方式等的深刻变革作用。如果你有更多具体的语境或者需要进一步调整的地方，可以随时告诉我。我还可以帮助你进行更多的翻译或者提供其他语言服务。

# %% [markdown]
# 调用对话模型

# %%
from openai import OpenAI
import os
import dotenv

dotenv.load_dotenv()

client = OpenAI(
    api_key=os.getenv("LLM_API_KEY"),
    base_url=os.getenv("LLM_BASE_URL")
)

# 使用 chat.completions 而不是 completions
response = client.chat.completions.create(
    model=os.getenv("LLM_MODEL_ID"),
    messages=[
        {"role": "user", "content": "请将以下英文翻译成中文：'Artificial intelligence will reshape the future.'"}
    ],
    max_tokens=100,
    temperature=0.7,
)

# 提取结果
print(response.choices[0].message.content)
# Out:
# 人工智能将重塑未来。

# %% [markdown]
# # 4、角度3：使用各个平台的API的调用大模型（了解）
#
# ## 4.1 OpenAI的方式
#
# 调用非对话模型

# %%
from openai import OpenAI
import os
import dotenv

dotenv.load_dotenv()

client = OpenAI(
    api_key=os.getenv("LLM_API_KEY"),
    base_url=os.getenv("LLM_BASE_URL")
)

# 使用 completions 而不是 chat.completions
response = client.completions.create(
    model=os.getenv("LLM_MODEL_ID"),
    prompt="请将以下英文翻译成中文：'Artificial intelligence will reshape the future.'",
    max_tokens=100,
    temperature=0.7,
)

# 提取结果
print(response.choices[0].text.strip())
# Out:
# '人工智能将会重新塑造未来。'

# %% [markdown]
# 调用对话模型

# %%
from openai import OpenAI
import os
import dotenv

dotenv.load_dotenv()

client = OpenAI(
    api_key=os.getenv("LLM_API_KEY"),
    base_url=os.getenv("LLM_BASE_URL")
)

# 使用 chat.completions 而不是 completions
response = client.chat.completions.create(
    model=os.getenv("LLM_MODEL_ID"),
    messages=[
        {"role": "user", "content": "请将以下英文翻译成中文：'Artificial intelligence will reshape the future.'"}
    ],
    max_tokens=100,
    temperature=0.7,
)

# 提取结果
print(response.choices[0].message.content)
# Out:
# 人工智能将重塑未来。

# %% [markdown]
# ## 4.2 百度千帆平台

# %%
from openai import OpenAI

client = OpenAI(
    api_key="",  # 千帆bearer token
    base_url="",  # 千帆域名
    default_headers={"appid": ""}   # 用户在千帆上的appid，非必传
)

completion = client.chat.completions.create(
    model="", # 预置服务请查看模型列表，定制服务请填入API地址
    messages=[{'role': 'system', 'content': 'You are a helpful assistant.'},
              {'role': 'user', 'content': 'Hello！'}]
)

print(completion.choices[0].message)

# %% [markdown]
# ## 4.3 使用阿里云百炼平台
#
# 方式1：使用OpenAI的方式

# %%
import os
from openai import OpenAI

client = OpenAI(
    # 若没有配置环境变量，请用阿里云百炼API Key将下行替换为：api_key="sk-xxx",
    api_key=os.getenv("DASHSCOPE_API_KEY"),  # 如何获取API Key：https://help.aliyun.com/zh/model-studio/developer-reference/get-api-key
    base_url=os.getenv("DASHSCOPE_BASE_URL")
)

completion = client.chat.completions.create(
    model="",  # 此处以 deepseek-r1 为例，可按需更换模型名称。
    messages=[
        {'role': 'user', 'content': '9.9和9.11谁大'}
    ]
)

# 通过reasoning_content字段打印思考过程
print("思考过程：")
print(completion.choices[0].message.reasoning_content)

# 通过content字段打印最终答案
print("最终答案：")
print(completion.choices[0].message.content)

# %% [markdown]
# 方式2：使用dashscope

# %%
import os
import dashscope

messages = [
    {'role': 'user', 'content': '你是谁？'}
]

response = dashscope.Generation.call(
    # 若没有配置环境变量，请用阿里云百炼API Key将下行替换为：api_key="sk-xxx",
    api_key=os.getenv('DASHSCOPE_API_KEY'),
    model="deepseek-r1",  # 此处以 deepseek-r1 为例，可按需更换模型名称。
    messages=messages,
    # result_format参数不可以设置为"text"。
    result_format='message'
)

print("=" * 20 + "思考过程" + "=" * 20)
print(response.output.choices[0].message.reasoning_content)
print("=" * 20 + "最终答案" + "=" * 20)
print(response.output.choices[0].message.content)

# %% [markdown]
# ## 4.4 智谱的GLM
#
# 方式1：使用OpenAI的方式

# %%
from openai import OpenAI

client = OpenAI(
    api_key="",
    base_url=""
)

completion = client.chat.completions.create(
    model="glm-4.5",
    messages=[
        {"role": "system", "content": "你是一个聪明且富有创造力的小说作家"},
        {"role": "user", "content": "请你作为童话故事大王，写一篇短篇童话故事"}
    ],
    top_p=0.7,
    temperature=0.9
)

print(completion.choices[0].message.content)

# %% [markdown]
# 方式2：使用langchain的方式

# %%
from langchain_openai import ChatOpenAI
from langchain.schema import HumanMessage, SystemMessage

# 创建LLM实例
llm = ChatOpenAI(
    temperature=0.7,
    model="",
    openai_api_key="",
    openai_api_base=""
)

# 创建消息
messages = [
    SystemMessage(content="你是一个有用的AI助手"),
    HumanMessage(content="请介绍一下人工智能的发展历程")
]

# 调用模型
response = llm(messages)
print(response.content)

# %% [markdown]
# ## 4.5 硅基流动平台的演示

# %%
import requests

url = "https://api.siliconflow.cn/v1/chat/completions"

payload = {
    "model": "Qwen/QwQ-32B",
    "messages": [
        {
            "role": "user",
            "content": "What opportunities and challenges will the Chinese large model industry face in 2025?"
        }
    ]
}
headers = {
    "Authorization": "Bearer ", # 填写自己的api-key
    "Content-Type": "application/json"
}

response = requests.post(url, json=payload, headers=headers)

print(response.json())
