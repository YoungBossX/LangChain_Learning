# %%
# 1、获取大模型
import os
import dotenv
from langchain_core.messages import AIMessage
from langchain_openai import ChatOpenAI

dotenv.load_dotenv()

os.environ['OPENAI_API_KEY'] = os.getenv("LLM_API_KEY")
os.environ['OPENAI_BASE_URL'] = os.getenv("LLM_BASE_URL")

# 创建大模型实例
llm = ChatOpenAI(model=os.getenv("LLM_MODEL_ID"))

# %%
from langchain_core.messages import HumanMessage
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.messages.ai import AIMessage


def chat_with_model(answer):
    # 2、提供提示词模板：ChatPromptTemplate
    prompt_template = ChatPromptTemplate.from_messages([
        ("system", "你是一个人工智能的助手"),
        ("human", "{question}")
    ])

    while True:
        # 3、获取chain，并调用大模型得到响应
        chain = prompt_template | llm
        response = chain.invoke({"question": answer})

        # 4、输出大模型的响应
        print(f"模型回复：{response.content}")

        # 5、继续获取用户的问题
        user_input = input("你还有其他问题吗？(输入'退出'时，结束会话)")

        # 6、指明退出循环的方式
        if (user_input == "退出"):
            break

        # 7、将上述新生成的消息存放到提示词模板的消息列表中
        prompt_template.messages.append(AIMessage(content=response.content))
        prompt_template.messages.append(HumanMessage(content=user_input))


chat_with_model("你好，很高兴认识你！")
# Out:
# 模型回复：你好！很高兴认识你！有什么问题或者需要帮助的可以随时告诉我。
# 模型回复：我是阿里云开发的语言模型，名为通义千问。作为一名人工智能助手，我被设计用来提供信息、回答问题和协助用户解决各种问题。
# 模型回复：我的模型名称是通义千问。
# 模型回复：不是的，我是通义千问模型。之前可能会有一些信息混淆，通义千问是阿里云开发的语言模型系列中的一员。如果有任何疑问或需要更多信息，欢迎随时提问！
# 模型回复：当然可以！杭州是中国浙江省的省会，是一座历史悠久、文化底蕴深厚的城市。以下是关于杭州的一些基本信息：
#
# 1. **地理位置**：位于浙江省北部，钱塘江畔，紧邻浙江省省会杭州市和上海、宁波等城市。
#
# 2. **城市特色**：
#    - **西湖**：是中国十大名胜之一，享有“人间天堂”的美誉。西湖周边有苏堤春晓、断桥残雪等众多景点。
#    - **历史人文**：有许多历史文化遗迹，如灵隐寺、六和塔、宋城等。
#    - **现代化城市**：作为一座现代化大城市，杭州也充满了现代气息，阿里集团和西湖大学等知名企业与高等学府坐落于此。
#
# 3. **经济**：杭州是浙江省的经济中心之一，互联网经济和高新技术产业发达，阿里巴巴集团总部就位于杭州。
#
# 4. **气候**：属于亚热带季风气候，四季分明，夏季炎热潮湿，冬季寒冷干燥，春秋温暖宜人。
#
# 5. **美食**：杭州菜是中国八大菜系之一的浙菜的重要组成部分，如西湖醋鱼、龙井虾仁、东坡肉等都是著名的当地美食。
#
# 6. **旅游**：除了自然风光和历史文化景点外，杭州还有许多现代化的旅游景点和购物中心，吸引了大量国内外游客。
#
# 杭州是一座融合了古典与现代的城市，无论是历史文化的爱好者还是现代都市的探索者，都能在这里找到适合自己的乐趣。
